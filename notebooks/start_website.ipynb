# %%
from selenium.webdriver import Firefox
from bs4 import BeautifulSoup

# %%
browser = Firefox()

# %%
browser.get('https://www.glassdoor.com')

# %%
html = browser.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
html
# Out:
# '<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" class="flex" lang="en"><head><title>Data Scientist Jobs in Seattle, WA | Glassdoor</title><link rel="shortcut icon" href="/favicon.ico" type="image/vnd.microsoft.icon"><link rel="icon" href="/favicon.ico" type="image/x-icon"><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width"><meta name="theme-color" content="#0caa41"><!-- Windows Phone --><meta name="msapplication-navbutton-color" content="#0caa41"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-status-bar-style" content="#0caa41"><link rel="apple-touch-icon-precomposed" href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-57.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b"><link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-72.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b"><link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-114.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b"><link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-144.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b"><link rel="manifest" href="/manifest.json"><meta name="description" content="Search Data Scientist jobs in Seattle, WA with company ratings &amp; salaries. 1,125 open jobs for Data Scientist in Seattle."><!-- SL:start:norewrite --><meta property="al:ios:app_store_id" content="589698942"><meta property="al:ios:app_name" content="Glassdoor"><link rel="canonical" href="https://www.glassdoor.com/Job/seattle-data-scientist-jobs-SRCH_IL.0,7_IC1150505_KO8,22.htm"><!-- SL:end:norewrite --><meta http-equiv="origin-trial" data-feature="getInstalledRelatedApps" data-expires="2017-12-26" content="At9LpmW/SGKoQafqVaHTfeX5N9lRrOEZw0dAoUrKiO21CAbclpg0c0XecEzX5QigJaDNvdHGhDU8tDKRRduS6AYAAABmeyJvcmlnaW4iOiJodHRwczovL2dsYXNzZG9vci5jb206NDQzIiwiZmVhdHVyZSI6Ikluc3RhbGxlZEFwcCIsImV4cGlyeSI6MTUxNDI1NjE5NCwiaXNTdWJkb21haW4iOnRydWV9"><meta http-equiv="Cache-Control" content="no-cache,must-revalidate"><meta http-equiv="Pragma" content="no-cache"><meta http-equiv="Expires" content="0"><link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet"><link href="https://www.glassdoor.com/jobs-ux-app/static/css/gd-job-search-core.css?v=10d72ad2zw" rel="stylesheet" type="text/css" media="all"><!-- because the getter clears the value --><script src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.VQ6xxTPj5B0.O/m=auth2/exm=client,plusone/rt=j/sv=1/d=1/ed=1/am=wQ/rs=AGLTcCNFXRcXVsNk2Fv2nIJdnyPDPqCUpw/cb=gapi.loaded_1" async=""></script><script src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.VQ6xxTPj5B0.O/m=client,plusone/rt=j/sv=1/d=1/ed=1/am=wQ/rs=AGLTcCNFXRcXVsNk2Fv2nIJdnyPDPqCUpw/cb=gapi.loaded_0" async=""></script><script type="text/javascript" async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js"></script><script type="text/javascript" async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js"></script><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=48243&amp;v=4.8.2&amp;p0=e%3Dexd%26site_type%3Dd&amp;p1=e%3Dvp%26p%3D1&amp;p2=e%3Dce%26m%3D%255B%255D&amp;p3=e%3Ddis&amp;adce=1&amp;lwid=40f6fc75-5799-441f-a4c9-caf9e8ca9ae2&amp;tld=glassdoor.com&amp;dtycbr=63642" data-owner="criteo-tag"></script><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=48243&amp;v=4.8.2&amp;p0=e%3Dexd%26site_type%3Dd&amp;p1=e%3Dce%26m%3D%255B%255D&amp;p2=e%3Dvl%26p%3D3008426758%252C3003044999%252C2933089828%252C2948038046%252C2296162134%252C3009543540%252C3001293396%252C2239836299%252C2966861875%252C2948038052%252C3047485386%252C3042575286%252C3010269833%252C3000602223%252C297 ...
