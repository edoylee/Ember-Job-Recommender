# %%
import pandas as pd
import numpy as np
from predictNew import CUSTOM_STOP, PruneForest, FitModel, Predict
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from scipy import spatial

# %%
data = PreprocessData()

# %%
total_df = data.transform('data/GLASSTEST.csv', 'data/profile.csv')

# %%
hot = pd.read_csv('data/HOTTEST.csv', index_col=0)

# %%
hot_transformed = data.transform('data/HOTTEST.csv', 'data/profile.csv')

# %%
culled_hot = hot_transformed.drop(index=0)

# %%
culled_hot
# Out:
#     indices                                             titles  \
# 1         9                                     Data Scientist
# 2         3                              Senior Data Scientist
# 3        10                                     Data Scientist
# 4         8                                   Data Scientist I
# 5         5                           Associate Data Scientist
# 6        12                                      Data Engineer
# 7         2                                     Data Scientist
# 8        11  Siri - Data Scientist (Machine Learning & Natu...
# 9         1                                Data Scientist, Sr.
# 10        4                                     Data Scientist
# 11        6  Scientist, Formulations, Viral Vector Process ...
# 12        7                         Machine Learning Scientist
#
#                                             companies  \
# 1                       4.5 ★H10 Capital– Seattle, WA
# ...

# %%
total_df = total_df.append(culled_hot, ignore_index=True)

# %%
total_df
# Out:
#     indices                                             titles  \
# 0         0                                                NaN
# 1         1                                     Data Scientist
# 2         2                                     Data Scientist
# 3         9                         Data Scientist - Verticals
# 4         8                              Senior Data Scientist
# 5         5                                   Data Scientist I
# 6        10                           Associate Data Scientist
# 7         6                                     Data Scientist
# 8         4                              Data Scientist - Risk
# 9         3                                Data Scientist, Sr.
# 10        7                                     Data Scientist
# 11        9                                     Data Scientist
# 12        3                              Senior Data Scientist
# 13       10                                     Data Scientist
# ...
